# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !apt update -y && apt install -y protobuf-compiler libprotobuf-dev libprotoc-dev g++ cmake python3-dev
# !protoc --version  # Check if Protobuf is installed
# !pip install --no-cache-dir pycld3
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:4 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [68.9 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,341 kB]0m
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import cld3

cld3.get_language("影響包含對氣候的變化以及自然資源的枯竭程度")
# Out:
# LanguagePrediction(language='zh', probability=0.999969482421875, is_reliable=True, proportion=1.0)

# %%
cld3.get_language("""
=====================================
           ACCORD BANCAIRE FRANÇAIS
=====================================

Type de document: Accord de transaction bancaire multilingue

CLIENT:
-------------------------------------
Nom: Jean Dupont
Adresse: 45 Rue de Rivoli, 75001 Paris, France
Numéro de compte: FR76 3000 6000 0112 3456 7890 189

BANQUE:
-------------------------------------
Nom de la banque: BNP Paribas
SWIFT: BNPAGFRPPXXX
IBAN: FR76 3000 6000 0112 3456 7890 189

DÉTAILS DE LA TRANSACTION:
-------------------------------------
Montant: €5,000,000.00
Devise: EUR
Date de valeur: 06 mars 2025
Référence de transaction: TXN-FR-2025-654321
Objet du paiement: Paiement d'investissement en obligations d'État

INSTRUCTIONS SPÉCIALES:
-------------------------------------
1. La transaction doit être validée conformément à la réglementation de la Banque de France et de l'Autorité des Marchés Financiers (AMF).
2. Les fonds sont bloqués jusqu'à réception de la confirmation de transfert par le bénéficiaire.
3. Toute anomalie détectée entraînera une enquête automatique par la cellule anti-fraude.

APPROBATION:
-------------------------------------
Signataire autorisé: Paul Martin (Directeur des Opérations, BNP Paribas)
Date: 05 mars 2025
Statut de la transaction: EN ATTENTE DE VÉRIFICATION

=====================================
REMARQUE: Ce document est soumis aux réglementations bancaires internationales.
=====================================""")
# Out:
# LanguagePrediction(language='fr', probability=0.99993896484375, is_reliable=True, proportion=1.0)

# %%
cld3.get_language("""=====================================
         बैंक गारंटी दस्तावेज़
=====================================

बैंक गारंटी संख्या: BG-2025-789456
जारी करने की तिथि: 01 मार्च 2025
समाप्ति तिथि: 01 मार्च 2026

गारंटीधारक: ABC इंफ्रास्ट्रक्चर लिमिटेड
फायदा उठाने वाला: XYZ कंस्ट्रक्शन प्राइवेट लिमिटेड
गारंटी राशि: ₹5,00,00,000 (पाँच करोड़ रुपए)

शर्तें एवं शर्तें:
1. यह बैंक गारंटी केवल XYZ कंस्ट्रक्शन प्राइवेट लिमिटेड को भुगतान की गारंटी के रूप में जारी की गई है।
2. भुगतान केवल तभी किया जाएगा जब XYZ कंस्ट्रक्शन इस गारंटी के तहत भुगतान की वैध मांग प्रस्तुत करेगा।
3. यह गारंटी 01 मार्च 2026 तक वैध रहेगी।
4. बैंक के निर्णय को अंतिम और बाध्यकारी माना जाएगा।

=====================================
अधिकार प्राप्त हस्ताक्षरकर्ता:
ABC बैंक, शाखा - नई दिल्ली
=====================================
""")
# Out:
# LanguagePrediction(language='hi', probability=0.9987000226974487, is_reliable=True, proportion=1.0)

# %%
for lang in cld3.get_frequent_languages(
     """=====================================
           EU BANKING AGREEMENT
=====================================

Dokumenttyp: Multilinguale Banktransaktionsvereinbarung  
Tipo de documento: Acuerdo bancario multilingüe  
Type de document : Accord bancaire multilingue  
Тип документа: Многоязычное банковское соглашение  

Kunde / Cliente / Client / Клиент: 
-------------------------------------
Name: Johann Müller (Germany)  
Nom: Jean Dupont (France)  
Nombre: Carlos Fernández (Spain)  
Имя: Иван Петров (Russia)  

Kontodaten / Datos de cuenta / Données du compte / Данные счета:
-------------------------------------
Bankname / Nombre del banco / Nom de la banque / Название банка: 
Deutsche Bank AG / Banco Santander / BNP Paribas / Сбербанк

SWIFT-Code: DEUTDEFFXXX / BSCHESMMXXX / BNPAGFRPPXXX / SABRRUMMXXX

IBAN: DE89 3704 0044 0532 0130 00 / ES91 2100 0418 4502 0005 1332 / FR76 3000 6000 0112 3456 7890 189 / RU21 044525225 12345678901234

Transaktionsdetails / Detalles de la transacción / Détails de la transaction / Детали транзакции:
-------------------------------------
Betrag / Cantidad / Montant / Сумма: €10,000,000.00  
Währung / Moneda / Devise / Валюта: EUR  
Transaktionsreferenz / Referencia de transacción / Référence de transaction / Номер транзакции: TXN-EU-2025-987654

Spezielle Bedingungen / Condiciones especiales / Conditions spéciales / Специальные условия:
-------------------------------------
1. Diese Transaktion unterliegt den Bestimmungen der Europäischen Zentralbank (EZB).  
   Esta transacción está sujeta a la normativa del Banco Central Europeo (BCE).  
   Cette transaction est soumise à la réglementation de la Banque centrale européenne (BCE).  
   Эта транзакция подчиняется нормативам Европейского центрального банка (ЕЦБ).  

2. Multinationale Überprüfung durch SWIFT und regulatorische Behörden erforderlich.  
   Revisión multinacional requerida por SWIFT y autoridades regulatorias.  
   Vérification multinationale requise par SWIFT et les autorités réglementaires.  
   Многонациональная проверка требуется SWIFT и регулирующими органами.  

Genehmigung / Aprobación / Approbation / Одобрение:
-------------------------------------
Unterschrift / Firma / Signature / Подпись: 
Johann Müller (Deutsche Bank) / Carlos Fernández (Banco Santander) / Jean Dupont (BNP Paribas) / Иван Петров (Сбербанк)

Datum / Fecha / Date / Дата: 05 März 2025 / 05 marzo 2025 / 05 mars 2025 / 05 марта 2025

=====================================
Hinweis / Aviso / Remarque / Примечание: Dieses Dokument unterliegt internationalen Bankvorschriften.
=====================================
""",
     num_langs=4
 ):
     print(lang)
# Out:
# LanguagePrediction(language='fr', probability=0.8555435538291931, is_reliable=True, proportion=0.24536629021167755)
# LanguagePrediction(language='ru', probability=0.9375666975975037, is_reliable=True, proportion=0.21270962059497833)
# LanguagePrediction(language='es', probability=0.7562674880027771, is_reliable=True, proportion=0.1641659289598465)
# LanguagePrediction(language='de', probability=0.9724022150039673, is_reliable=True, proportion=0.14165930449962616)

# %%
for lang in cld3.get_frequent_languages(
     """=====================================
         البنك الوطني - بیان حساب
=====================================

صاحب الحساب / مالک حساب / دارنده حساب: احمد الفارسي

رقم الحساب / اکاؤنٹ نمبر / شماره حساب: 5678-9012-3456

تفاصيل المعاملات / لین دین کی تفصیل / جزئیات تراکنش‌ها:
-------------------------------------
التاريخ / تاریخ / تاریخ       | الوصف / تفصیل / توضیحات          | المبلغ (SAR) / رقم (SAR) / مقدار (SAR) | الرصيد (SAR) / بیلنس (SAR) / مانده (SAR)
-------------------------------------
2025/03/01  | إيداع الراتب / تنخواہ جمع / واریز حقوق   | +15,000.00    | 40,000.00
2025/03/02  | دفع فاتورة الكهرباء / بجلی کا بل ادا / پرداخت قبض برق  | -300.00      | 39,700.00
2025/03/05  | صدقة / صدقہ / صدقه               | -500.00       | 39,200.00
2025/03/07  | مصاريف مطعم / ریستوران کے اخراجات / هزینه‌های رستوران  | -250.00       | 38,950.00
2025/03/10  | سحب نقدي / نقدی نکالنا / برداشت وجه نقد  | -1,000.00     | 37,950.00

-------------------------------------

الرصيد النهائي / آخری بیلنس / مانده نهایی: 37,950.00 SAR

=====================================
خدمة العملاء / کسٹمر سروس / خدمات مشتریان: +966-1234-5678
=====================================
""",
     num_langs=3
 ):
     print(lang)
# Out:
# LanguagePrediction(language='fa', probability=0.9740628600120544, is_reliable=True, proportion=0.4586864411830902)
# LanguagePrediction(language='ar', probability=0.5323525667190552, is_reliable=False, proportion=0.40783897042274475)
# LanguagePrediction(language='ur', probability=0.8403862714767456, is_reliable=True, proportion=0.08792372792959213)

# %%
for lang in cld3.get_frequent_languages(
     """=====================================
      XYZ BANK - ACCOUNT STATEMENT
=====================================

Account Holder: John Doe
Titulaire du compte: John Doe
लेखाकारी: जॉन डो

Account Number: 1234-5678-9012
Numéro de compte: 1234-5678-9012
खाता संख्या: 1234-5678-9012

Statement Period: 01 Feb 2025 - 28 Feb 2025
Période de relevé: 01 Février 2025 - 28 Février 2025
विवरण काल: 01 फरवरी 2025 - 28 फरवरी 2025

-------------------------------------
Date          Description            Amount
-------------------------------------
01/02/2025    Salary Credit         +$3,000.00
Salaire crédité                   +$3,000.00
वेतन जारी                       +$3,000.00

05/02/2025    ATM Withdrawal       -$500.00
Retrait ATM                        -$500.00
ATM माध्यम                            -$500.00

12/02/2025    Grocery Store        -$120.75
Magasin d'épicerie                 -$120.75
किराना की दुकान                      -$120.75

20/02/2025    Online Purchase      -$45.99
Achat en ligne                      -$45.99
ऑनलाइन खरीद                     -$45.99

27/02/2025    Interest Credit      +$10.50
Crédit d'intérêt                   +$10.50
सुध जोड़ा                      +$10.50

-------------------------------------
Closing Balance: $2,344.76
Solde de clôture: $2,344.76
अंतिम शेष राशि: $2,344.76

=====================================
For inquiries, call: +1-800-XYZ-BANK
Pour toute question, appelez: +1-800-XYZ-BANK
किसी भी प्रश्न के लिए: +1-800-XYZ-BANK
=====================================
""",
     num_langs=3
 ):
     print(lang)
# Out:
# LanguagePrediction(language='fr', probability=0.8608735799789429, is_reliable=True, proportion=0.4693641662597656)
# LanguagePrediction(language='mr', probability=0.9425873756408691, is_reliable=True, proportion=0.21040461957454681)
# LanguagePrediction(language='hi', probability=0.8329559564590454, is_reliable=True, proportion=0.161849707365036)
